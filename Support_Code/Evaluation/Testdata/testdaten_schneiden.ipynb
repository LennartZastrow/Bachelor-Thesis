# %% [markdown]
# ### Testdatenverarbeitung(Schneiden + Sortieren) Audio

# %%
import os
from moviepy.editor import AudioFileClip

# Zähler für jede Emotion initialisieren
datei_zähler = {}

def schneiden_und_verschieben(tabelle, basis_pfad, ziel_ordner, emotion_name):
    global datei_zähler
    
    
    # Iteriere über jede Zeile in der Tabelle
    for zeile in tabelle:
        name_emotion, zeiten = zeile[0], zeile[1]
        name, _ = name_emotion.split('(')
        startzeit, endzeit = zeiten.split('-')
        
        # Konvertiere Zeiten von Minuten:Sekunden in reine Sekunden
        start_min, start_sec = map(int, startzeit.split(':'))
        end_min, end_sec = map(int, endzeit.split(':'))
        start_seconds = start_min * 60 + start_sec
        end_seconds = end_min * 60 + end_sec
        
        # Aktualisiere den Zähler für die angegebene Emotion
        if emotion_name not in datei_zähler:
            datei_zähler[emotion_name] = 1
        else:
            datei_zähler[emotion_name] += 1
        
        # Pfad zur ursprünglichen Datei
        original_datei_pfad = os.path.join(basis_pfad, name.strip(), f"{name.strip()}_{emotion_name}.m4a")
        
        # Ziel-Dateipfad ohne Zeitsequenz, nur mit Zähler
        ziel_datei_name = f"{emotion_name}{datei_zähler[emotion_name]}.m4a"
        ziel_datei_pfad = os.path.join(ziel_ordner, ziel_datei_name)
        
        # Schneide die Audiodatei und speichere sie
        with AudioFileClip(original_datei_pfad) as audio:
            new_audio = audio.subclip(start_seconds, end_seconds)
            new_audio.write_audiofile(ziel_datei_pfad, codec='aac')  # Verwende 'aac' als Codec

# Basispfad, wo die Originaldateien gespeichert sind
basis_pfad = "C:\\Users\\zastr\\Desktop\\Thesis\\Data\\Audio"

# Zielordner für jede Emotion
ziel_ordner_freude = "C:\\Users\\zastr\\Desktop\\Thesis\\Data\\Testdata\\Sprache\\Freude"
pfad_trauer = "C:\\Users\\zastr\\Desktop\\Thesis\\Data\\Testdata\\Sprache\\Trauer"
pfad_ekel = "C:\\Users\\zastr\\Desktop\\Thesis\\Data\\Testdata\\Sprache\\Ekel"
pfad_angst = "C:\\Users\\zastr\\Desktop\\Thesis\\Data\\Testdata\\Sprache\\Angst"

# Freude
tabelle_freude = [
    ["Benny(Freude)", "3:08-3:14"],
    ["Benny(Allgemein)", "2:24-2:28"],
    ["Emily(Allgemein)", "2:03-2:04"],
    ["Emily(Freude)", "0:54-1:03"],
    ["Emily(Freude)", "2:21-2:31"],
    ["Tim(Freude)", "0:12-0:16"],
    ["Tim(Freude)", "1:16-1:18"],
    ["Henrike(Freude)", "1:32-1:37"],
    ["Henrike(Freude)", "3:41-3:48"],
    ["Lemki(Allgemein)", "0:40-0:45"],
    ["Lemki(Allgemein)", "2:18-2:21"],
    ["Lemki(Allgemein)", "2:24-2:28"]
]

# Trauer
tabelle_trauer = [
    ["Benny(Trauer)", "1:53-2:04"],
    ["Benny(Trauer)", "4:17-4:25"],
    ["Benny(Trauer)", "2:55-3:02"],
    ["Lemki(Trauer)", "3:53-3:57"],
    ["Henrike(Trauer)", "1:38-1:43"],
    ["Henrike(Trauer)", "3:38-3:42"],
    ["Henrike(Trauer)", "4:27-4:29"],
    ["Tim(Trauer)", "2:47-2:54"],
    ["Tim(Trauer)", "3:11-3:20"],
    ["Tim(Trauer)", "4:13-4:18"],
    ["Emily(Trauer)", "5:32-5:36"],
    ["Emily(Trauer)", "7:32-7:41"],
    ["Emily(Trauer)", "11:00-11:10"]
]

# Ekel
tabelle_ekel = [
    ["Benny(Ekel)", "2:26-2:31"],
    ["Benny(Ekel)", "2:35-2:40"],
    ["Benny(Ekel)", "0:38-0:40"],
    ["Lemki(Ekel)", "0:41-0:42"],
    ["Lemki(Ekel)", "1:33-1:38"],
    ["Henrike(Ekel)", "0:06-0:08"],
    ["Henrike(Ekel)", "0:24-0:28"],
    ["Henrike(Ekel)", "1:52-1:58"],
    ["Tim(Ekel)", "3:05-3:10"],
    ["Tim(Ekel)", "3:10-3:16"],
    ["Tim(Ekel)", "3:17-3:24"],
    ["Emily(Ekel)", "1:54-1:55"],
    ["Emily(Ekel)", "3:07-3:11"],
    ["Emily(Ekel)", "4:48-4:52"]
]

# Angst
tabelle_angst = [
    ["Benny(Angst)", "1:10-1:18"],
    ["Benny(Angst)", "1:50-1:54"],
    ["Benny(Angst)", "1:54-1:59"],
    ["Lemki(Angst)", "2:04-2:10"],
    ["Lemki(Angst)", "2:35-2:40"],
    ["Lemki(Angst)", "1:53-1:58"],
    ["Henrike(Angst)", "2:21-2:25"],
    ["Henrike(Angst)", "1:30-1:31"],
    ["Tim(Angst)", "1:33-1:37"],
    ["Tim(Angst)", "2:56-3:04"],
    ["Tim(Angst)", "3:20-3:26"],
    ["Emily(Trauer)", "1:00-1:05"],  
    ["Emily(Trauer)", "0:55-1:00"]   
]

# Funktion aufrufen für jede Emotion mit dem entsprechenden Zielordner und Emotionsname 
schneiden_und_verschieben(tabelle_freude, basis_pfad, ziel_ordner_freude, "Freude")
schneiden_und_verschieben(tabelle_trauer, basis_pfad, pfad_trauer, "Trauer")
schneiden_und_verschieben(tabelle_ekel, basis_pfad, pfad_ekel, "Ekel")
schneiden_und_verschieben(tabelle_angst, basis_pfad, pfad_angst, "Angst")

# %% [markdown]
# ### Testdatenverarbeitung(Sortieren + Umbennen) Mimik Freude

# %%
import os
import shutil

# Zähler für Dateien initialisieren
datei_zähler = 1

def kopieren_und_benennen(dateipfade, ziel_ordner):
    global datei_zähler
    
    # Stelle sicher, dass der Zielordner existiert
    if not os.path.exists(ziel_ordner):
        os.makedirs(ziel_ordner)
        
    for pfad in dateipfade:
        # Ziel-Dateiname
        ziel_dateiname = f"Freude{datei_zähler}.jpg"
        ziel_pfad = os.path.join(ziel_ordner, ziel_dateiname)
        
        # Kopiere die Datei
        shutil.move(pfad, ziel_pfad)
        print(f"Datei wurde kopiert und umbenannt zu {ziel_dateiname}")
        
        # Zähler erhöhen
        datei_zähler += 1

# Liste der Dateipfade
dateipfade = [
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Freude\Benny_freude_192_193_14.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Freude\Benny_freude_080_081_13.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Freude\Emily_freude_126_132_19.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Freude\Emily_freude_056_062_7.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Freude\Emily_freude_141_142_22.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Freude\Tim_freude_016_018_18.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Freude\Tim_freude_075_077_15.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Freude\Henrike_freude_162_166_97.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Freude\Henrike_freude_162_166_90.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Freude\Lemki_freude_038_040_33.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Freude\Lemki_freude_137_140_19.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Freude\Lemki_freude_168_171_25.jpg_gesicht.jpg"
]

# Zielordner für die kopierten und umbenannten Dateien
ziel_ordner = r"C:\Users\zastr\Desktop\Thesis\Data\Testdata\Mimik\Freude"

# Funktion aufrufen
kopieren_und_benennen(dateipfade, ziel_ordner)
# Out:
# Datei wurde kopiert und umbenannt zu Freude1.jpg
# Datei wurde kopiert und umbenannt zu Freude2.jpg
# Datei wurde kopiert und umbenannt zu Freude3.jpg
# Datei wurde kopiert und umbenannt zu Freude4.jpg
# Datei wurde kopiert und umbenannt zu Freude5.jpg
# Datei wurde kopiert und umbenannt zu Freude6.jpg
# Datei wurde kopiert und umbenannt zu Freude7.jpg
# Datei wurde kopiert und umbenannt zu Freude8.jpg
# Datei wurde kopiert und umbenannt zu Freude9.jpg
# Datei wurde kopiert und umbenannt zu Freude10.jpg
# Datei wurde kopiert und umbenannt zu Freude11.jpg
# Datei wurde kopiert und umbenannt zu Freude12.jpg

# %% [markdown]
# ### Testdatenverarbeitung(Sortieren + Umbennen) Mimik Trauer

# %%
import os
import shutil

# Zähler für Dateien initialisieren
datei_zähler_trauer = 1

def kopieren_und_benennen_trauer(dateipfade, ziel_ordner):
    global datei_zähler_trauer
    
    # Stelle sicher, dass der Zielordner existiert
    if not os.path.exists(ziel_ordner):
        os.makedirs(ziel_ordner)
        
    for pfad in dateipfade:
        # Ziel-Dateiname
        ziel_dateiname = f"Trauer{datei_zähler_trauer}.jpg"
        ziel_pfad = os.path.join(ziel_ordner, ziel_dateiname)
        
        # Kopiere die Datei
        shutil.move(pfad, ziel_pfad)
        print(f"Datei wurde kopiert und umbenannt zu {ziel_dateiname}")
        
        # Zähler erhöhen
        datei_zähler_trauer += 1

# Liste der Dateipfade für Trauer
dateipfade_trauer = [
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Trauer\Benny_trauer_120_121_26.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Trauer\Benny_trauer_264_265_18.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Trauer\Benny_trauer_179_180_6.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Trauer\Lemki_trauer_235_236_12.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Trauer\Henrike_trauer_190_193_18.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Trauer\Henrike_trauer_218_219_24.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Trauer\Henrike_trauer_261_263_26.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Trauer\Tim_trauer_146_148_25.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Trauer\Tim_trauer_198_201_69.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Trauer\Tim_trauer_251_252_14.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Trauer\Emily_trauer_333_334_18.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Trauer\Emily_trauer_459_460_10.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Trauer\Emily_trauer_668_669_14.jpg_gesicht.jpg"
]

# Zielordner für die kopierten und umbenannten Dateien
ziel_ordner_trauer = r"C:\Users\zastr\Desktop\Thesis\Data\Testdata\Mimik\Trauer"

# Funktion aufrufen
kopieren_und_benennen_trauer(dateipfade_trauer, ziel_ordner_trauer)
# Out:
# Datei wurde kopiert und umbenannt zu Trauer1.jpg
# Datei wurde kopiert und umbenannt zu Trauer2.jpg
# Datei wurde kopiert und umbenannt zu Trauer3.jpg
# Datei wurde kopiert und umbenannt zu Trauer4.jpg
# Datei wurde kopiert und umbenannt zu Trauer5.jpg
# Datei wurde kopiert und umbenannt zu Trauer6.jpg
# Datei wurde kopiert und umbenannt zu Trauer7.jpg
# Datei wurde kopiert und umbenannt zu Trauer8.jpg
# Datei wurde kopiert und umbenannt zu Trauer9.jpg
# Datei wurde kopiert und umbenannt zu Trauer10.jpg
# Datei wurde kopiert und umbenannt zu Trauer11.jpg
# Datei wurde kopiert und umbenannt zu Trauer12.jpg
# Datei wurde kopiert und umbenannt zu Trauer13.jpg

# %% [markdown]
# ### Testdatenverarbeitung(Sortieren + Umbennen) Mimik Ekel

# %%
import os
import shutil

# Zähler für Dateien initialisieren
datei_zähler = 1

def kopieren_und_benennen_ekel(dateipfade, ziel_ordner):
    global datei_zähler
    
    # Stelle sicher, dass der Zielordner existiert
    if not os.path.exists(ziel_ordner):
        os.makedirs(ziel_ordner)
        
    for pfad in dateipfade:
        # Ziel-Dateiname
        ziel_dateiname = f"Ekel{datei_zähler}.jpg"
        ziel_pfad = os.path.join(ziel_ordner, ziel_dateiname)
        
        # Kopiere die Datei
        shutil.move(pfad, ziel_pfad)
        print(f"Datei wurde kopiert und umbenannt zu {ziel_dateiname}")
        
        # Zähler erhöhen
        datei_zähler += 1

# Liste der Dateipfade für Ekel
dateipfade_ekel = [
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Ekel\Benny_ekel_150_151_11.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Ekel\Benny_ekel_155_156_14.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Ekel\Benny_ekel_036_038_47.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Ekel\Lemki_ekel_043_052_28.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Ekel\Lemki_ekel_156_157_18.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Ekel\Henrike_ekel_006_007_17.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Ekel\Henrike_ekel_032_033_22.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Ekel\Henrike_ekel_118_119_8.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Ekel\Tim_ekel_193_194_12.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Ekel\Tim_ekel_193_194_21.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Ekel\Emily_ekel_177_178_16.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Ekel\Emily_ekel_187_188_19.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Ekel\Emily_ekel_282_284_40.jpg_gesicht.jpg"
]

# Zielordner für die kopierten und umbenannten Dateien für Ekel
ziel_ordner_ekel = r"C:\Users\zastr\Desktop\Thesis\Data\Testdata\Mimik\Ekel"

# Funktion aufrufen für Ekel
kopieren_und_benennen_ekel(dateipfade_ekel, ziel_ordner_ekel)
# Out:
# Datei wurde kopiert und umbenannt zu Ekel1.jpg
# Datei wurde kopiert und umbenannt zu Ekel2.jpg
# Datei wurde kopiert und umbenannt zu Ekel3.jpg
# Datei wurde kopiert und umbenannt zu Ekel4.jpg
# Datei wurde kopiert und umbenannt zu Ekel5.jpg
# Datei wurde kopiert und umbenannt zu Ekel6.jpg
# Datei wurde kopiert und umbenannt zu Ekel7.jpg
# Datei wurde kopiert und umbenannt zu Ekel8.jpg
# Datei wurde kopiert und umbenannt zu Ekel9.jpg
# Datei wurde kopiert und umbenannt zu Ekel10.jpg
# Datei wurde kopiert und umbenannt zu Ekel11.jpg
# Datei wurde kopiert und umbenannt zu Ekel12.jpg
# Datei wurde kopiert und umbenannt zu Ekel13.jpg

# %% [markdown]
# ### Testdatenverarbeitung(Sortieren + Umbennen) Mimik Angst

# %%
import os
import shutil

# Zähler für Dateien initialisieren
datei_zähler = 1

def kopieren_und_benennen_angst(dateipfade, ziel_ordner):
    global datei_zähler
    
    # Stelle sicher, dass der Zielordner existiert
    if not os.path.exists(ziel_ordner):
        os.makedirs(ziel_ordner)
        
    for pfad in dateipfade:
        # Ziel-Dateiname
        ziel_dateiname = f"Angst{datei_zähler}.jpg"
        ziel_pfad = os.path.join(ziel_ordner, ziel_dateiname)
        
        # Kopiere die Datei
        shutil.move(pfad, ziel_pfad)
        print(f"Datei wurde kopiert und umbenannt zu {ziel_dateiname}")
        
        # Zähler erhöhen
        datei_zähler += 1

# Liste der Dateipfade für Angst
dateipfade_angst = [
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Angst\Benny_angst_112_113_2.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Angst\Benny_angst_112_113_14.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Angst\Lemki_angst_128_129_14.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Angst\Lemki_angst_155_158_25.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Angst\Lemki_angst_117_118_22.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Angst\Henrike_angst_146_147_3.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Angst\Henrike_angst_096_097_11.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Angst\Tim_angst_100_101_10.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Angst\Tim_angst_172_173_23.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Angst\Tim_angst_207_208_8.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Angst\Emily_angst_065_066_8.jpg_gesicht.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Facial_Expressions\Angst\Emily_angst_057_058_9.jpg_gesicht.jpg"
]

# Zielordner für die kopierten und umbenannten Dateien für Angst
ziel_ordner_angst = r"C:\Users\zastr\Desktop\Thesis\Data\Testdata\Mimik\Angst"

# Funktion aufrufen für Angst
kopieren_und_benennen_angst(dateipfade_angst, ziel_ordner_angst)
# Out:
# Datei wurde kopiert und umbenannt zu Angst1.jpg
# Datei wurde kopiert und umbenannt zu Angst2.jpg
# Datei wurde kopiert und umbenannt zu Angst3.jpg
# Datei wurde kopiert und umbenannt zu Angst4.jpg
# Datei wurde kopiert und umbenannt zu Angst5.jpg
# Datei wurde kopiert und umbenannt zu Angst6.jpg
# Datei wurde kopiert und umbenannt zu Angst7.jpg
# Datei wurde kopiert und umbenannt zu Angst8.jpg
# Datei wurde kopiert und umbenannt zu Angst9.jpg
# Datei wurde kopiert und umbenannt zu Angst10.jpg
# Datei wurde kopiert und umbenannt zu Angst11.jpg
# Datei wurde kopiert und umbenannt zu Angst12.jpg

# %% [markdown]
# ### Testdatenverarbeitung(Sortieren + Umbennen) Körpersprache Freude

# %%
import os
import shutil

# Zähler für Dateien initialisieren
datei_zähler = 1

def kopieren_und_benennen_koerpersprache_freude(dateipfade, ziel_ordner):
    global datei_zähler
    
    # Stelle sicher, dass der Zielordner existiert
    if not os.path.exists(ziel_ordner):
        os.makedirs(ziel_ordner)
        
    for pfad in dateipfade:
        # Ziel-Dateiname
        ziel_dateiname = f"Freude{datei_zähler}.jpg"
        ziel_pfad = os.path.join(ziel_ordner, ziel_dateiname)
        
        # Kopiere die Datei
        shutil.move(pfad, ziel_pfad)
        print(f"Datei wurde kopiert und umbenannt zu {ziel_dateiname}")
        
        # Zähler erhöhen
        datei_zähler += 1

# Liste der Dateipfade für Freude in Körpersprache
dateipfade_koerpersprache_freude = [
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Freude\Benny_freude_192_193_14.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Freude\Benny_freude_080_081_13.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Freude\Emily_freude_126_132_13.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Freude\Emily_freude_056_062_7.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Freude\Emily_freude_141_142_23.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Freude\Tim_freude_016_018_18.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Freude\Tim_freude_075_077_15.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Freude\Henrike_freude_162_166_97.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Freude\Henrike_freude_162_166_90.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Freude\Lemki_freude_038_040_33.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Freude\Lemki_freude_137_140_19.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Freude\Lemki_freude_168_171_25.jpg"
]

# Zielordner für die kopierten und umbenannten Dateien für Freude in Körpersprache
ziel_ordner_koerpersprache_freude = r"C:\Users\zastr\Desktop\Thesis\Data\Testdata\Körpersprache\Freude"

# Funktion aufrufen für Freude in Körpersprache
kopieren_und_benennen_koerpersprache_freude(dateipfade_koerpersprache_freude, ziel_ordner_koerpersprache_freude)
# Out:
# Datei wurde kopiert und umbenannt zu Freude1.jpg
# Datei wurde kopiert und umbenannt zu Freude2.jpg
# Datei wurde kopiert und umbenannt zu Freude3.jpg
# Datei wurde kopiert und umbenannt zu Freude4.jpg
# Datei wurde kopiert und umbenannt zu Freude5.jpg
# Datei wurde kopiert und umbenannt zu Freude6.jpg
# Datei wurde kopiert und umbenannt zu Freude7.jpg
# Datei wurde kopiert und umbenannt zu Freude8.jpg
# Datei wurde kopiert und umbenannt zu Freude9.jpg
# Datei wurde kopiert und umbenannt zu Freude10.jpg
# Datei wurde kopiert und umbenannt zu Freude11.jpg
# Datei wurde kopiert und umbenannt zu Freude12.jpg

# %% [markdown]
# ### Testdatenverarbeitung(Sortieren + Umbennen) Körpersprache Trauer

# %%
import os
import shutil

# Zähler für Dateien initialisieren
datei_zähler = 1

def kopieren_und_benennen_koerpersprache_trauer(dateipfade, ziel_ordner):
    global datei_zähler
    
    # Stelle sicher, dass der Zielordner existiert
    if not os.path.exists(ziel_ordner):
        os.makedirs(ziel_ordner)
        
    for pfad in dateipfade:
        # Ziel-Dateiname
        ziel_dateiname = f"Trauer{datei_zähler}.jpg"
        ziel_pfad = os.path.join(ziel_ordner, ziel_dateiname)
        
        # Kopiere die Datei
        shutil.move(pfad, ziel_pfad)
        print(f"Datei wurde kopiert und umbenannt zu {ziel_dateiname}")
        
        # Zähler erhöhen
        datei_zähler += 1

# Liste der Dateipfade für Trauer in Körpersprache
dateipfade_koerpersprache_trauer = [
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Trauer\Benny_trauer_120_121_26.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Trauer\Benny_trauer_264_265_18.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Trauer\Benny_trauer_179_180_6.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Trauer\Lemki_trauer_235_236_12.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Trauer\Henrike_trauer_190_193_18.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Trauer\Henrike_trauer_218_219_24.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Trauer\Henrike_trauer_261_263_26.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Trauer\Tim_trauer_146_148_25.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Trauer\Tim_trauer_198_201_69.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Trauer\Tim_trauer_251_252_14.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Trauer\Emily_trauer_333_334_18.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Trauer\Emily_trauer_459_460_24.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Trauer\Emily_trauer_668_669_18.jpg"
]

# Zielordner für die kopierten und umbenannten Dateien für Trauer in Körpersprache
ziel_ordner_koerpersprache_trauer = r"C:\Users\zastr\Desktop\Thesis\Data\Testdata\Körpersprache\Trauer"

# Funktion aufrufen für Trauer in Körpersprache
kopieren_und_benennen_koerpersprache_trauer(dateipfade_koerpersprache_trauer, ziel_ordner_koerpersprache_trauer)
# Out:
# Datei wurde kopiert und umbenannt zu Trauer1.jpg
# Datei wurde kopiert und umbenannt zu Trauer2.jpg
# Datei wurde kopiert und umbenannt zu Trauer3.jpg
# Datei wurde kopiert und umbenannt zu Trauer4.jpg
# Datei wurde kopiert und umbenannt zu Trauer5.jpg
# Datei wurde kopiert und umbenannt zu Trauer6.jpg
# Datei wurde kopiert und umbenannt zu Trauer7.jpg
# Datei wurde kopiert und umbenannt zu Trauer8.jpg
# Datei wurde kopiert und umbenannt zu Trauer9.jpg
# Datei wurde kopiert und umbenannt zu Trauer10.jpg
# Datei wurde kopiert und umbenannt zu Trauer11.jpg
# Datei wurde kopiert und umbenannt zu Trauer12.jpg
# Datei wurde kopiert und umbenannt zu Trauer13.jpg

# %% [markdown]
# ### Testdatenverarbeitung(Sortieren + Umbennen) Körpersprache Ekel

# %%
import os
import shutil

# Zähler für Dateien initialisieren
datei_zähler = 1

def kopieren_und_benennen_koerpersprache_ekel(dateipfade, ziel_ordner):
    global datei_zähler
    
    # Stelle sicher, dass der Zielordner existiert
    if not os.path.exists(ziel_ordner):
        os.makedirs(ziel_ordner)
        
    for pfad in dateipfade:
        # Ziel-Dateiname
        ziel_dateiname = f"Ekel{datei_zähler}.jpg"
        ziel_pfad = os.path.join(ziel_ordner, ziel_dateiname)
        
        # Kopiere die Datei
        shutil.move(pfad, ziel_pfad)
        print(f"Datei wurde kopiert und umbenannt zu {ziel_dateiname}")
        
        # Zähler erhöhen
        datei_zähler += 1

# Liste der Dateipfade für Ekel in Körpersprache
dateipfade_koerpersprache_ekel = [
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Ekel\Benny_ekel_150_151_5.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Ekel\Benny_ekel_155_156_17.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Ekel\Benny_ekel_036_038_31.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Ekel\Lemki_ekel_156_157_21.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Ekel\Henrike_ekel_006_007_15.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Ekel\Henrike_ekel_032_033_15.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Ekel\Henrike_ekel_118_119_4.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Ekel\Tim_ekel_193_194_12.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Ekel\Tim_ekel_193_194_23.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Ekel\Emily_ekel_177_178_8.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Ekel\Emily_ekel_187_188_22.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Ekel\Emily_ekel_282_284_44.jpg"
]


# Zielordner für die kopierten und umbenannten Dateien für Ekel in Körpersprache
ziel_ordner_koerpersprache_ekel = r"C:\Users\zastr\Desktop\Thesis\Data\Testdata\Körpersprache\Ekel"

# Funktion aufrufen für Ekel in Körpersprache
kopieren_und_benennen_koerpersprache_ekel(dateipfade_koerpersprache_ekel, ziel_ordner_koerpersprache_ekel)
# Out:
# Datei wurde kopiert und umbenannt zu Ekel1.jpg
# Datei wurde kopiert und umbenannt zu Ekel2.jpg
# Datei wurde kopiert und umbenannt zu Ekel3.jpg
# Datei wurde kopiert und umbenannt zu Ekel4.jpg
# Datei wurde kopiert und umbenannt zu Ekel5.jpg
# Datei wurde kopiert und umbenannt zu Ekel6.jpg
# Datei wurde kopiert und umbenannt zu Ekel7.jpg
# Datei wurde kopiert und umbenannt zu Ekel8.jpg
# Datei wurde kopiert und umbenannt zu Ekel9.jpg
# Datei wurde kopiert und umbenannt zu Ekel10.jpg
# Datei wurde kopiert und umbenannt zu Ekel11.jpg
# Datei wurde kopiert und umbenannt zu Ekel12.jpg

# %% [markdown]
# ### Testdatenverarbeitung(Sortieren + Umbennen) Körpersprache Angst

# %%
import os
import shutil

# Zähler für Dateien initialisieren
datei_zähler = 1

def kopieren_und_benennen_koerpersprache_angst(dateipfade, ziel_ordner):
    global datei_zähler
    
    # Stelle sicher, dass der Zielordner existiert
    if not os.path.exists(ziel_ordner):
        os.makedirs(ziel_ordner)
        
    for pfad in dateipfade:
        # Ziel-Dateiname
        ziel_dateiname = f"Angst{datei_zähler}.jpg"
        ziel_pfad = os.path.join(ziel_ordner, ziel_dateiname)
        
        # Kopiere die Datei
        shutil.move(pfad, ziel_pfad)
        print(f"Datei wurde kopiert und umbenannt zu {ziel_dateiname}")
        
        # Zähler erhöhen
        datei_zähler += 1

# Liste der Dateipfade für Angst in Körpersprache
dateipfade_koerpersprache_angst = [
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Angst\Benny_angst_112_113_4.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Angst\Benny_angst_112_113_15.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Angst\Lemki_angst_128_129_16.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Angst\Lemki_angst_155_158_19.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Angst\Lemki_angst_117_118_22.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Angst\Henrike_angst_146_147_4.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Angst\Henrike_angst_096_097_11.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Angst\Tim_angst_100_101_12.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Angst\Tim_angst_172_173_23.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Angst\Tim_angst_207_208_9.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Angst\Emily_angst_065_066_8.jpg",
    r"C:\Users\zastr\Desktop\Thesis\Data\Frames\Fullbody\Angst\Emily_angst_057_058_9.jpg"
]

# Zielordner für die kopierten und umbenannten Dateien für Angst in Körpersprache
ziel_ordner_koerpersprache_angst = r"C:\Users\zastr\Desktop\Thesis\Data\Testdata\Körpersprache\Angst"

# Funktion aufrufen für Angst in Körpersprache
kopieren_und_benennen_koerpersprache_angst(dateipfade_koerpersprache_angst, ziel_ordner_koerpersprache_angst)
# Out:
# Datei wurde kopiert und umbenannt zu Angst1.jpg
# Datei wurde kopiert und umbenannt zu Angst2.jpg
# Datei wurde kopiert und umbenannt zu Angst3.jpg
# Datei wurde kopiert und umbenannt zu Angst4.jpg
# Datei wurde kopiert und umbenannt zu Angst5.jpg
# Datei wurde kopiert und umbenannt zu Angst6.jpg
# Datei wurde kopiert und umbenannt zu Angst7.jpg
# Datei wurde kopiert und umbenannt zu Angst8.jpg
# Datei wurde kopiert und umbenannt zu Angst9.jpg
# Datei wurde kopiert und umbenannt zu Angst10.jpg
# Datei wurde kopiert und umbenannt zu Angst11.jpg
# Datei wurde kopiert und umbenannt zu Angst12.jpg
